# %%
import math
import torch
import gpytorch
#import spectralgp
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

torch.set_default_dtype(torch.float64)
seed = np.random.randint(42)
print(seed)
torch.random.manual_seed(seed)
# Out:
# 35

# %% [markdown]
# #### Processing training Data
#
# Here we setup a function to load training data as well as randomly split the data for train/test.

# %%
def read_data(dataset, only_scale = False, **kwargs):
    D = loadmat("/Users/wesleymaddox/Documents/GitHub/spectralgp/exps_multi_input_dim/data/{}.mat".format(dataset))
    data = np.array(D['data'])
    train_x, test_x, train_y, test_y = train_test_split(data[:, :-1], data[:, -1], test_size=0.10, random_state=np.random.randint(10000))
    train_x = torch.tensor(train_x)
    train_y = torch.tensor(train_y)
    test_x = torch.tensor(test_x)
    test_y = torch.tensor(test_y)

    y_std_train = torch.std(train_y)
    y_std_full = torch.std(torch.cat([train_y, test_y]))

    return train_x, train_y, test_x, test_y, y_std_full, y_std_train, _

# %%
dataset = 'servo2'

print("Dataset: {}".format(dataset))
train_x, train_y, test_x, test_y, y_std, y_std_train, gen_kern = read_data(dataset)
in_dims = 1 if train_x.dim() == 1 else train_x.size(1)
# Out:
# Dataset: servo2

# %% [markdown]
# #### GPU support
#
# If CUDA is available, we can simply just change the datatypes of the training/test tensor to the appropriate datatype.

# %%
use_cuda = torch.cuda.is_available()
print('Cuda is available', use_cuda)
if use_cuda:
    torch.set_default_tensor_type(torch.cuda.DoubleTensor)
    train_x, train_y, test_x, test_y, y_std = train_x.cuda(), train_y.cuda(), test_x.cuda(), test_y.cuda(), y_std.cuda()
    if gen_kern is not None:
        gen_kern = gen_kern.cuda()

print("Input Dimensions {}".format(in_dims))
# Out:
# Cuda is available False
# Input Dimensions 4

# %% [markdown]
# #### Set up the GPyTorch Model with Spectral Product GP kernel
#
# Using the same framework as standard GPyTorch models, we merely drop-in the product spectral GP kernel as the covar module.
#
# For specifics on the components of GPyTorch models we refer to the [GPyTorch Documentation](https://gpytorch.readthedocs.io/en/latest/index.html)

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood, shared, **kwargs):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ProductSpectralGPKernel(train_x, train_y, shared, **kwargs)
    
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
likelihood = gpytorch.likelihoods.GaussianLikelihood(noise_prior=gpytorch.priors.SmoothedBoxPrior(1e-8, 1e-3))
model = ExactGPModel(train_x, train_y, likelihood, shared=False, 
                     normalize = False, symmetrize = False, num_locs = 100,
                     spacing='random', omega_max = 8., pretrain=False, nonstat=True)
# Out:
# (1e-10, 8.0)
# (1e-10, 8.0)
# (1e-10, 8.0)
# (1e-10, 8.0)

# %% [markdown]
# #### Setup Sampling Factories and Alternating Sampler
#
# In the inference procedure we consider fixing the latent GP observation and doing gradient descent updates on the hyperparameters, then fixing the hyperparameters and using elliptical slice sampling to update the latent GP.
#
# The ss_factory generates a "factory" that fixes the latent GP and computes the loss function of the hyperparameters

# %%
alt_sampler = gpytorch.samplers.AlternatingSampler(
    [model], [likelihood], 
    gpytorch.samplers.ss_factory, [gpytorch.samplers.ess_factory],
    totalSamples=20, numInnerSamples=5, numOuterSamples=5,
    num_dims=in_dims
    )

# %%
alt_sampler.run()
# Out:
# Step:  0 Dimension:  0
# Loss is:  tensor(-205.9670, grad_fn=<DivBackward0>)
# Loss is:  tensor(-201.8051, grad_fn=<DivBackward0>)
# Loss is:  tensor(-197.7972, grad_fn=<DivBackward0>)
# Loss is:  tensor(-193.9060, grad_fn=<DivBackward0>)
# Loss is:  tensor(-190.0489, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 0
# Step:  0 Dimension:  1
# Loss is:  tensor(-186.1749, grad_fn=<DivBackward0>)
# Loss is:  tensor(-182.4518, grad_fn=<DivBackward0>)
# Loss is:  tensor(-179.1080, grad_fn=<DivBackward0>)
# Loss is:  tensor(-175.1791, grad_fn=<DivBackward0>)
# Loss is:  tensor(-171.9567, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 0
# Step:  0 Dimension:  2
# Loss is:  tensor(-168.4513, grad_fn=<DivBackward0>)
# Loss is:  tensor(-165.2669, grad_fn=<DivBackward0>)
# Loss is:  tensor(-161.9995, grad_fn=<DivBackward0>)
# Loss is:  tensor(-158.8237, grad_fn=<DivBackward0>)
# Loss is:  tensor(-155.6961, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 0
# Step:  0 Dimension:  3
# Loss is:  tensor(-152.7566, grad_fn=<DivBackward0>)
# Loss is:  tensor(-149.6893, grad_fn=<DivBackward0>)
# Loss is:  tensor(-146.8222, grad_fn=<DivBackward0>)
# Loss is:  tensor(-143.9524, grad_fn=<DivBackward0>)
# Loss is:  tensor(-141.0972, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 0
# Seconds for Iteration 0 : 25.72867202758789
# Step:  1 Dimension:  0
# Loss is:  tensor(-138.2986, grad_fn=<DivBackward0>)
# Loss is:  tensor(-135.5602, grad_fn=<DivBackward0>)
# Loss is:  tensor(-133.0261, grad_fn=<DivBackward0>)
# Loss is:  tensor(-130.3453, grad_fn=<DivBackward0>)
# Loss is:  tensor(-127.8554, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 1
# Step:  1 Dimension:  1
# Loss is:  tensor(-125.1846, grad_fn=<DivBackward0>)
# Loss is:  tensor(-122.7937, grad_fn=<DivBackward0>)
# Loss is:  tensor(-120.4624, grad_fn=<DivBackward0>)
# Loss is:  tensor(-118.0976, grad_fn=<DivBackward0>)
# Loss is:  tensor(-115.8837, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 1
# Step:  1 Dimension:  2
# Loss is:  tensor(-113.6499, grad_fn=<DivBackward0>)
# Loss is:  tensor(-111.4196, grad_fn=<DivBackward0>)
# Loss is:  tensor(-109.2238, grad_fn=<DivBackward0>)
# Loss is:  tensor(-107.1198, grad_fn=<DivBackward0>)
# Loss is:  tensor(-105.0550, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 1
# Step:  1 Dimension:  3
# Loss is:  tensor(-102.8103, grad_fn=<DivBackward0>)
# Loss is:  tensor(-100.9299, grad_fn=<DivBackward0>)
# Loss is:  tensor(-98.9326, grad_fn=<DivBackward0>)
# Loss is:  tensor(-97.0318, grad_fn=<DivBackward0>)
# Loss is:  tensor(-95.1164, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 1
# Seconds for Iteration 1 : 26.32835602760315
# Step:  2 Dimension:  0
# Loss is:  tensor(-93.1931, grad_fn=<DivBackward0>)
# Loss is:  tensor(-91.6103, grad_fn=<DivBackward0>)
# Loss is:  tensor(-89.8340, grad_fn=<DivBackward0>)
# Loss is:  tensor(-88.1659, grad_fn=<DivBackward0>)
# Loss is:  tensor(-86.5421, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 2
# Step:  2 Dimension:  1
# Loss is:  tensor(-84.7980, grad_fn=<DivBackward0>)
# Loss is:  tensor(-83.2458, grad_fn=<DivBackward0>)
# Loss is:  tensor(-81.7043, grad_fn=<DivBackward0>)
# Loss is:  tensor(-80.2248, grad_fn=<DivBackward0>)
# Loss is:  tensor(-78.5878, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 2
# Step:  2 Dimension:  2
# Loss is:  tensor(-76.6912, grad_fn=<DivBackward0>)
# Loss is:  tensor(-75.3342, grad_fn=<DivBackward0>)
# Loss is:  tensor(-73.8888, grad_fn=<DivBackward0>)
# Loss is:  tensor(-72.5581, grad_fn=<DivBackward0>)
# Loss is:  tensor(-71.3033, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 2
# Step:  2 Dimension:  3
# Loss is:  tensor(-69.6794, grad_fn=<DivBackward0>)
# Loss is:  tensor(-68.4827, grad_fn=<DivBackward0>)
# Loss is:  tensor(-67.1367, grad_fn=<DivBackward0>)
# Loss is:  tensor(-65.8124, grad_fn=<DivBackward0>)
# Loss is:  tensor(-64.6766, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 2
# Seconds for Iteration 2 : 26.064942836761475
# Step:  3 Dimension:  0
# Loss is:  tensor(-63.5765, grad_fn=<DivBackward0>)
# Loss is:  tensor(-62.2942, grad_fn=<DivBackward0>)
# Loss is:  tensor(-61.1548, grad_fn=<DivBackward0>)
# Loss is:  tensor(-60.1626, grad_fn=<DivBackward0>)
# Loss is:  tensor(-58.8415, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 3
# Step:  3 Dimension:  1
# Loss is:  tensor(-57.7800, grad_fn=<DivBackward0>)
# Loss is:  tensor(-56.8134, grad_fn=<DivBackward0>)
# Loss is:  tensor(-55.7453, grad_fn=<DivBackward0>)
# Loss is:  tensor(-54.7773, grad_fn=<DivBackward0>)
# Loss is:  tensor(-53.8451, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 3
# Step:  3 Dimension:  2
# Loss is:  tensor(-52.7333, grad_fn=<DivBackward0>)
# Loss is:  tensor(-51.7763, grad_fn=<DivBackward0>)
# Loss is:  tensor(-50.9011, grad_fn=<DivBackward0>)
# Loss is:  tensor(-49.9804, grad_fn=<DivBackward0>)
# Loss is:  tensor(-49.0485, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 3
# Step:  3 Dimension:  3
# Loss is:  tensor(-48.0561, grad_fn=<DivBackward0>)
# Loss is:  tensor(-47.1544, grad_fn=<DivBackward0>)
# Loss is:  tensor(-46.3191, grad_fn=<DivBackward0>)
# Loss is:  tensor(-45.5751, grad_fn=<DivBackward0>)
# Loss is:  tensor(-44.6291, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 3
# Seconds for Iteration 3 : 25.35530114173889
# Step:  4 Dimension:  0
# Loss is:  tensor(-43.8089, grad_fn=<DivBackward0>)
# Loss is:  tensor(-43.0685, grad_fn=<DivBackward0>)
# Loss is:  tensor(-42.3235, grad_fn=<DivBackward0>)
# Loss is:  tensor(-41.4801, grad_fn=<DivBackward0>)
# Loss is:  tensor(-40.8797, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 4
# Step:  4 Dimension:  1
# Loss is:  tensor(-40.0922, grad_fn=<DivBackward0>)
# Loss is:  tensor(-39.4012, grad_fn=<DivBackward0>)
# Loss is:  tensor(-38.7633, grad_fn=<DivBackward0>)
# Loss is:  tensor(-38.1621, grad_fn=<DivBackward0>)
# Loss is:  tensor(-37.4612, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 4
# Step:  4 Dimension:  2
# Loss is:  tensor(-36.5655, grad_fn=<DivBackward0>)
# Loss is:  tensor(-36.0688, grad_fn=<DivBackward0>)
# Loss is:  tensor(-35.4319, grad_fn=<DivBackward0>)
# Loss is:  tensor(-34.8226, grad_fn=<DivBackward0>)
# Loss is:  tensor(-34.2906, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 4
# Step:  4 Dimension:  3
# Loss is:  tensor(-33.6671, grad_fn=<DivBackward0>)
# Loss is:  tensor(-32.9810, grad_fn=<DivBackward0>)
# Loss is:  tensor(-32.5978, grad_fn=<DivBackward0>)
# Loss is:  tensor(-31.9921, grad_fn=<DivBackward0>)
# Loss is:  tensor(-31.4844, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 4
# Seconds for Iteration 4 : 25.37973380088806
# Step:  5 Dimension:  0
# Loss is:  tensor(-30.8988, grad_fn=<DivBackward0>)
# Loss is:  tensor(-30.4370, grad_fn=<DivBackward0>)
# Loss is:  tensor(-29.9273, grad_fn=<DivBackward0>)
# Loss is:  tensor(-29.4962, grad_fn=<DivBackward0>)
# Loss is:  tensor(-28.9305, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 5
# Step:  5 Dimension:  1
# Loss is:  tensor(-28.4434, grad_fn=<DivBackward0>)
# Loss is:  tensor(-28.0401, grad_fn=<DivBackward0>)
# Loss is:  tensor(-27.6633, grad_fn=<DivBackward0>)
# Loss is:  tensor(-27.0791, grad_fn=<DivBackward0>)
# Loss is:  tensor(-26.7864, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 5
# Step:  5 Dimension:  2
# Loss is:  tensor(-26.2792, grad_fn=<DivBackward0>)
# Loss is:  tensor(-25.8398, grad_fn=<DivBackward0>)
# Loss is:  tensor(-25.5346, grad_fn=<DivBackward0>)
# Loss is:  tensor(-25.1463, grad_fn=<DivBackward0>)
# Loss is:  tensor(-24.7208, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 5
# Step:  5 Dimension:  3
# Loss is:  tensor(-24.0585, grad_fn=<DivBackward0>)
# Loss is:  tensor(-23.7035, grad_fn=<DivBackward0>)
# Loss is:  tensor(-23.3051, grad_fn=<DivBackward0>)
# Loss is:  tensor(-22.9170, grad_fn=<DivBackward0>)
# Loss is:  tensor(-22.6551, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 5
# Seconds for Iteration 5 : 16.540448904037476
# Step:  6 Dimension:  0
# Loss is:  tensor(-22.1588, grad_fn=<DivBackward0>)
# Loss is:  tensor(-21.8073, grad_fn=<DivBackward0>)
# Loss is:  tensor(-21.5749, grad_fn=<DivBackward0>)
# Loss is:  tensor(-21.1664, grad_fn=<DivBackward0>)
# Loss is:  tensor(-21.0189, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 6
# Step:  6 Dimension:  1
# Loss is:  tensor(-20.5230, grad_fn=<DivBackward0>)
# Loss is:  tensor(-20.2840, grad_fn=<DivBackward0>)
# Loss is:  tensor(-20.0117, grad_fn=<DivBackward0>)
# Loss is:  tensor(-19.7846, grad_fn=<DivBackward0>)
# Loss is:  tensor(-19.3437, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 6
# Step:  6 Dimension:  2
# Loss is:  tensor(-18.7810, grad_fn=<DivBackward0>)
# Loss is:  tensor(-18.5311, grad_fn=<DivBackward0>)
# Loss is:  tensor(-18.2620, grad_fn=<DivBackward0>)
# Loss is:  tensor(-17.9922, grad_fn=<DivBackward0>)
# Loss is:  tensor(-17.6808, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 6
# Step:  6 Dimension:  3
# Loss is:  tensor(-17.4391, grad_fn=<DivBackward0>)
# Loss is:  tensor(-17.1421, grad_fn=<DivBackward0>)
# Loss is:  tensor(-16.8930, grad_fn=<DivBackward0>)
# Loss is:  tensor(-16.6517, grad_fn=<DivBackward0>)
# Loss is:  tensor(-16.5025, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 6
# Seconds for Iteration 6 : 15.175377130508423
# Step:  7 Dimension:  0
# Loss is:  tensor(-16.2183, grad_fn=<DivBackward0>)
# Loss is:  tensor(-15.9855, grad_fn=<DivBackward0>)
# Loss is:  tensor(-15.6437, grad_fn=<DivBackward0>)
# Loss is:  tensor(-15.4770, grad_fn=<DivBackward0>)
# Loss is:  tensor(-15.3843, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 7
# Step:  7 Dimension:  1
# Loss is:  tensor(-14.5474, grad_fn=<DivBackward0>)
# Loss is:  tensor(-14.3171, grad_fn=<DivBackward0>)
# Loss is:  tensor(-14.1224, grad_fn=<DivBackward0>)
# Loss is:  tensor(-13.9837, grad_fn=<DivBackward0>)
# Loss is:  tensor(-13.7025, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 7
# Step:  7 Dimension:  2
# Loss is:  tensor(-13.4579, grad_fn=<DivBackward0>)
# Loss is:  tensor(-13.3396, grad_fn=<DivBackward0>)
# Loss is:  tensor(-13.2369, grad_fn=<DivBackward0>)
# Loss is:  tensor(-13.0257, grad_fn=<DivBackward0>)
# Loss is:  tensor(-12.8863, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 7
# Step:  7 Dimension:  3
# Loss is:  tensor(-12.5168, grad_fn=<DivBackward0>)
# Loss is:  tensor(-12.3824, grad_fn=<DivBackward0>)
# Loss is:  tensor(-12.2201, grad_fn=<DivBackward0>)
# Loss is:  tensor(-12.0753, grad_fn=<DivBackward0>)
# Loss is:  tensor(-11.9186, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 7
# Seconds for Iteration 7 : 17.99086904525757
# Step:  8 Dimension:  0
# Loss is:  tensor(-11.6839, grad_fn=<DivBackward0>)
# Loss is:  tensor(-11.5729, grad_fn=<DivBackward0>)
# Loss is:  tensor(-11.4001, grad_fn=<DivBackward0>)
# Loss is:  tensor(-11.2741, grad_fn=<DivBackward0>)
# Loss is:  tensor(-11.1654, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 8
# Step:  8 Dimension:  1
# Loss is:  tensor(-10.8522, grad_fn=<DivBackward0>)
# Loss is:  tensor(-10.6588, grad_fn=<DivBackward0>)
# Loss is:  tensor(-10.6586, grad_fn=<DivBackward0>)
# Loss is:  tensor(-10.5126, grad_fn=<DivBackward0>)
# Loss is:  tensor(-10.3719, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 8
# Step:  8 Dimension:  2
# Loss is:  tensor(-10.0072, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.9138, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.8178, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.7066, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.6362, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 8
# Step:  8 Dimension:  3
# Loss is:  tensor(-9.4262, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.3451, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.1889, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.1508, grad_fn=<DivBackward0>)
# Loss is:  tensor(-9.0437, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 8
# Seconds for Iteration 8 : 16.682997941970825
# Step:  9 Dimension:  0
# Loss is:  tensor(-8.7251, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.6846, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.6167, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.5364, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.4547, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 9
# Step:  9 Dimension:  1
# Loss is:  tensor(-8.3001, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.2712, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.1675, grad_fn=<DivBackward0>)
# Loss is:  tensor(-8.1052, grad_fn=<DivBackward0>)
# Loss is:  tensor(-7.9988, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 9
# Step:  9 Dimension:  2
# Loss is:  tensor(-7.7235, grad_fn=<DivBackward0>)
# Loss is:  tensor(-7.6629, grad_fn=<DivBackward0>)
# Loss is:  tensor(-7.5808, grad_fn=<DivBackward0>)
# Loss is:  tensor(-7.5337, grad_fn=<DivBackward0>)
# Loss is:  tensor(-7.4674, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 9
# Step:  9 Dimension:  3
# Loss is:  tensor(-7.0892, grad_fn=<DivBackward0>)
# Loss is:  tensor(-7.0373, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.9936, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.9453, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.8868, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 9
# Seconds for Iteration 9 : 14.584828853607178
# Step:  10 Dimension:  0
# Loss is:  tensor(-6.6482, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.5827, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.5621, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.4982, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.5006, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 10
# Step:  10 Dimension:  1
# Loss is:  tensor(-6.2648, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.2187, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.1089, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.1204, grad_fn=<DivBackward0>)
# Loss is:  tensor(-6.1058, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 10
# Step:  10 Dimension:  2
# Loss is:  tensor(-5.9486, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.9018, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.8781, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.8527, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.7788, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 10
# Step:  10 Dimension:  3
# Loss is:  tensor(-5.7488, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.7083, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.6756, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.6181, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.6236, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 10
# Seconds for Iteration 10 : 18.508162021636963
# Step:  11 Dimension:  0
# Loss is:  tensor(-5.2603, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.2102, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.1574, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.1755, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.1162, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 11
# Step:  11 Dimension:  1
# Loss is:  tensor(-5.0732, grad_fn=<DivBackward0>)
# Loss is:  tensor(-5.0568, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.9835, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.9854, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.9428, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 11
# Step:  11 Dimension:  2
# Loss is:  tensor(-4.7494, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.7446, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.6848, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.6542, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.6563, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 11
# Step:  11 Dimension:  3
# Loss is:  tensor(-4.4985, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.4823, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.4877, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.4327, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.3766, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 11
# Seconds for Iteration 11 : 13.750797748565674
# Step:  12 Dimension:  0
# Loss is:  tensor(-4.2944, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.2324, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.2357, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.2000, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.1719, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 12
# Step:  12 Dimension:  1
# Loss is:  tensor(-4.0684, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.0328, grad_fn=<DivBackward0>)
# Loss is:  tensor(-4.0182, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.9565, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.9721, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 12
# Step:  12 Dimension:  2
# Loss is:  tensor(-3.8965, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.9057, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.8697, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.8603, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.8247, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 12
# Step:  12 Dimension:  3
# Loss is:  tensor(-3.7047, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.7144, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.6638, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.6588, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.6439, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 12
# Seconds for Iteration 12 : 14.912564992904663
# Step:  13 Dimension:  0
# Loss is:  tensor(-3.6147, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.6175, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.5919, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.5724, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.5565, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 13
# Step:  13 Dimension:  1
# Loss is:  tensor(-3.5291, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.5403, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.5209, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.4940, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.4922, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 13
# Step:  13 Dimension:  2
# Loss is:  tensor(-3.4627, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.4621, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.4260, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.4239, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.3999, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 13
# Step:  13 Dimension:  3
# Loss is:  tensor(-3.4174, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.3918, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.3779, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.3708, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.3465, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 13
# Seconds for Iteration 13 : 18.372631072998047
# Step:  14 Dimension:  0
# Loss is:  tensor(-3.1829, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.2120, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1801, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1738, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1683, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 14
# Step:  14 Dimension:  1
# Loss is:  tensor(-3.1474, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1700, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1474, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1077, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.1202, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 14
# Step:  14 Dimension:  2
# Loss is:  tensor(-3.0809, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.0626, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.0523, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.0632, grad_fn=<DivBackward0>)
# Loss is:  tensor(-3.0797, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 14
# Step:  14 Dimension:  3
# Loss is:  tensor(-3.0111, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9923, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9751, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9755, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9609, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 14
# Seconds for Iteration 14 : 18.312952280044556
# Step:  15 Dimension:  0
# Loss is:  tensor(-2.9758, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9697, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9676, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9621, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9617, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 15
# Step:  15 Dimension:  1
# Loss is:  tensor(-2.9116, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.9195, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8971, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8953, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8808, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 15
# Step:  15 Dimension:  2
# Loss is:  tensor(-2.8635, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8748, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8496, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8595, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.8462, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 15
# Step:  15 Dimension:  3
# Loss is:  tensor(-2.7860, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7680, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7449, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7707, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7528, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 15
# Seconds for Iteration 15 : 16.53227686882019
# Step:  16 Dimension:  0
# Loss is:  tensor(-2.7659, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7546, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7475, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7471, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.7462, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 16
# Step:  16 Dimension:  1
# Loss is:  tensor(-2.6881, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6917, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6703, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6521, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6779, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 16
# Step:  16 Dimension:  2
# Loss is:  tensor(-2.6376, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6319, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6214, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6263, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6149, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 16
# Step:  16 Dimension:  3
# Loss is:  tensor(-2.6358, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6087, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6098, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6165, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6338, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 16
# Seconds for Iteration 16 : 16.057666063308716
# Step:  17 Dimension:  0
# Loss is:  tensor(-2.6086, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.5875, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.5819, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6179, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.5760, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 17
# Step:  17 Dimension:  1
# Loss is:  tensor(-2.5840, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6113, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.6233, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.5806, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.5600, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 17
# Step:  17 Dimension:  2
# Loss is:  tensor(-2.4243, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4571, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4661, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4373, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4372, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 17
# Step:  17 Dimension:  3
# Loss is:  tensor(-2.4277, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4403, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4025, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4419, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.4221, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 17
# Seconds for Iteration 17 : 15.619174242019653
# Step:  18 Dimension:  0
# Loss is:  tensor(-2.3332, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.3534, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.3140, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2974, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.3183, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 18
# Step:  18 Dimension:  1
# Loss is:  tensor(-2.2712, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.3046, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2581, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2500, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2775, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 18
# Step:  18 Dimension:  2
# Loss is:  tensor(-2.2161, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2170, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2043, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1818, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.2037, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 18
# Step:  18 Dimension:  3
# Loss is:  tensor(-2.1425, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1924, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1526, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1603, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1238, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 18
# Seconds for Iteration 18 : 19.87134289741516
# Step:  19 Dimension:  0
# Loss is:  tensor(-2.1637, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1615, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1622, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1402, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1321, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 19
# Step:  19 Dimension:  1
# Loss is:  tensor(-2.0930, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0951, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0673, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.1002, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0844, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 19
# Step:  19 Dimension:  2
# Loss is:  tensor(-2.0293, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0397, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0434, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0497, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0543, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 19
# Step:  19 Dimension:  3
# Loss is:  tensor(-2.0491, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0690, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0636, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0513, grad_fn=<DivBackward0>)
# Loss is:  tensor(-2.0392, grad_fn=<DivBackward0>)
# Task: 0 ; Iteration 19
# Seconds for Iteration 19 : 16.438771963119507

# %%
model.eval()
likelihood.eval()

d = model(test_x).mean - test_y

test_rmse = torch.sqrt(torch.mean(torch.pow(d, 2)))
print("Test RMSE: {}".format(test_rmse))

y_preds = likelihood(model(test_x))
y_var = y_preds.variance

nll = 0.5 * torch.log(2. * math.pi * y_var) +  torch.pow((model(test_x).mean - test_y),2)/(2. * y_var)
nll_sum = nll.sum()
print("NLL: {}".format(nll_sum))

sll = nll - (0.5 * torch.log(2. * math.pi * torch.pow(y_std_train, 2)) +  torch.pow((torch.mean(train_y) - test_y),2)/(2. * torch.pow(y_std_train, 2)))
msll = torch.mean(sll)
print("MSLL: {}".format(msll))
# Out:
# Test RMSE: 0.47440974700206545
# NLL: 13.73754301029132
# MSLL: -0.5433085510987413

# %%
alt_sampler.gsampled[0].size()
# Out:
# torch.Size([1, 100, 100])

# %%
colors = ['navy', 'orange', 'teal', 'red']

for dim in range(in_dims):
    # get last 10 samples for current dimension
    dim_samples = alt_sampler.gsampled[dim][0, :,-10:]
    
    omega = model.covar_module.get_omega(dim).cpu().numpy()
    
    plt.plot(omega, dim_samples.exp().cpu().numpy(), color=colors[dim], alpha = 0.5)
plt.grid()

plt.xlabel('Omega', fontsize=16)
plt.ylabel('S(Omega)', fontsize = 16)
plt.xlim((0, 3))
plt.ylim((0, 2))
plt.title('Spectral Densities by Dimension, Servo')
# Out:
# Text(0.5, 1.0, 'Spectral Densities by Dimension, Servo')
