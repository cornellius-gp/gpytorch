# %% [markdown]
# # Scalable GP Classification (w/ KISS-GP)
#
# This example shows how to use a `GridInducingVariationalGP` module. This classification module is designed for when the function you're modeling has 2-3 dimensional inputs and you don't believe that the output can be additively decomposed.
#
# In this example, the function is checkerboard of 1/3x1/3 squares with labels of -1 or 1
#
#
#  Here we use KISS-GP (https://arxiv.org/pdf/1503.01057.pdf) to classify

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
from math import exp

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# We make an nxn grid of training points
# In [0,1]x[0,1] spaced every 1/(n-1)
n = 30
train_x = torch.zeros(int(pow(n, 2)), 2)
train_y = torch.zeros(int(pow(n, 2)))
for i in range(n):
    for j in range(n):
        train_x[i * n + j][0] = float(i) / (n - 1)
        train_x[i * n + j][1] = float(j) / (n - 1)
        # True function is checkerboard of 1/3x1/3 squares with labels of -1 or 1
        train_y[i * n + j] = pow(-1, int(3 * i / n + int(3 * j / n)))

# %%
from gpytorch.models.new_variational_gp import NewVariationalGP
from gpytorch.variational.variational_distribution import VariationalDistribution
from gpytorch.variational.grid_interpolation_variational_strategy import GridInterpolationVariationalStrategy

class GPClassificationModel(NewVariationalGP):
    def __init__(self, grid_size=10, grid_bounds=[(0, 1), (0, 1)]):
        variational_distribution = VariationalDistribution(int(pow(grid_size, len(grid_bounds))))
        variational_strategy = GridInterpolationVariationalStrategy(self, grid_size, grid_bounds, variational_distribution)
        super(GPClassificationModel, self).__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(
                log_lengthscale_prior=gpytorch.priors.SmoothedBoxPrior(
                    exp(0), exp(3), sigma=0.1, log_transform=True
                )
            )
        )
        
    def forward(self,x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        latent_pred = gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
        return latent_pred


model = GPClassificationModel()
likelihood = gpytorch.likelihoods.BernoulliLikelihood()

# %%
from gpytorch.mlls.variational_elbo import VariationalELBO

# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.SGD([
    {'params': model.parameters()},
    # BernoulliLikelihood has no parameters
], lr=0.1)

# "Loss" for GPs - the marginal log likelihood
# n_data refers to the amount of training data
mll = VariationalELBO(likelihood, model, train_y.size(0))

def train():
    num_iter = 200
    for i in range(num_iter):
        optimizer.zero_grad()
        variational_dist_f, variational_dist_u, prior_dist = model(train_x)
        # Calc loss and backprop gradients
        loss = -mll(variational_dist_f, variational_dist_u, prior_dist, train_y)
        loss.backward()
        print('Iter %d/%d - Loss: %.3f' % (i + 1, num_iter, loss.item()))
        optimizer.step()
        
# Get clock time
# %time train()
# Out:
# torch.Size([900, 16]) torch.Size([100])
# Iter 1/200 - Loss: 48.487
# torch.Size([900, 16]) torch.Size([100])
# Iter 2/200 - Loss: 32.969
# torch.Size([900, 16]) torch.Size([100])
# Iter 3/200 - Loss: 0.943
# torch.Size([900, 16]) torch.Size([100])
# Iter 4/200 - Loss: 0.881
# torch.Size([900, 16]) torch.Size([100])
# Iter 5/200 - Loss: 0.960
# torch.Size([900, 16]) torch.Size([100])
# Iter 6/200 - Loss: 0.943
# torch.Size([900, 16]) torch.Size([100])
# Iter 7/200 - Loss: 0.940
# torch.Size([900, 16]) torch.Size([100])
# Iter 8/200 - Loss: 0.943
# torch.Size([900, 16]) torch.Size([100])
# Iter 9/200 - Loss: 0.901
# torch.Size([900, 16]) torch.Size([100])
# Iter 10/200 - Loss: 0.948
# torch.Size([900, 16]) torch.Size([100])
# Iter 172/200 - Loss: 0.746
# torch.Size([900, 16]) torch.Size([100])
# Iter 173/200 - Loss: 0.813
# torch.Size([900, 16]) torch.Size([100])
# Iter 174/200 - Loss: 0.796
# torch.Size([900, 16]) torch.Size([100])
# Iter 175/200 - Loss: 0.773
# torch.Size([900, 16]) torch.Size([100])
# Iter 176/200 - Loss: 0.815
# torch.Size([900, 16]) torch.Size([100])
# Iter 177/200 - Loss: 0.755
# torch.Size([900, 16]) torch.Size([100])
# Iter 178/200 - Loss: 0.766
# torch.Size([900, 16]) torch.Size([100])
# Iter 179/200 - Loss: 0.803
# torch.Size([900, 16]) torch.Size([100])
# Iter 180/200 - Loss: 0.756
# torch.Size([900, 16]) torch.Size([100])
# Iter 181/200 - Loss: 0.763
# torch.Size([900, 16]) torch.Size([100])
# Iter 182/200 - Loss: 0.766
# torch.Size([900, 16]) torch.Size([100])
# Iter 183/200 - Loss: 0.754
# torch.Size([900, 16]) torch.Size([100])
# Iter 184/200 - Loss: 0.762
# torch.Size([900, 16]) torch.Size([100])
# Iter 185/200 - Loss: 0.786
# torch.Size([900, 16]) torch.Size([100])
# Iter 186/200 - Loss: 0.766
# torch.Size([900, 16]) torch.Size([100])
# Iter 187/200 - Loss: 0.764
# torch.Size([900, 16]) torch.Size([100])
# Iter 188/200 - Loss: 0.763
# torch.Size([900, 16]) torch.Size([100])
# Iter 189/200 - Loss: 0.778
# torch.Size([900, 16]) torch.Size([100])
# Iter 190/200 - Loss: 0.750
# torch.Size([900, 16]) torch.Size([100])
# Iter 191/200 - Loss: 0.770
# torch.Size([900, 16]) torch.Size([100])
# Iter 192/200 - Loss: 0.730
# torch.Size([900, 16]) torch.Size([100])
# Iter 193/200 - Loss: 0.756
# torch.Size([900, 16]) torch.Size([100])
# Iter 194/200 - Loss: 0.766
# torch.Size([900, 16]) torch.Size([100])
# Iter 195/200 - Loss: 0.757
# torch.Size([900, 16]) torch.Size([100])
# Iter 196/200 - Loss: 0.768
# torch.Size([900, 16]) torch.Size([100])
# Iter 197/200 - Loss: 0.752
# torch.Size([900, 16]) torch.Size([100])
# Iter 198/200 - Loss: 0.738
# torch.Size([900, 16]) torch.Size([100])
# Iter 199/200 - Loss: 0.766
# torch.Size([900, 16]) torch.Size([100])
# Iter 200/200 - Loss: 0.795
# CPU times: user 1min 16s, sys: 2.2 s, total: 1min 18s
# Wall time: 11.8 s

# %%
# Set model and likelihood into eval mode
model.eval()
likelihood.eval()

# Initialize figiure an axis
f, ax = plt.subplots(1, 1, figsize=(4, 3))

n = 100
test_x = torch.zeros(int(pow(n, 2)), 2)
for i in range(n):
    for j in range(n):
        test_x[i * n + j][0] = float(i) / (n-1)
        test_x[i * n + j][1] = float(j) / (n-1)
        
with torch.no_grad(), gpytorch.beta_features.fast_pred_var():
    predictions = likelihood(model(test_x))

# prob<0.5 --> label -1 // prob>0.5 --> label 1
pred_labels = predictions.mean.ge(0.5).float().mul(2).sub(1).numpy()
# Colors = yellow for 1, red for -1
color = []
for i in range(len(pred_labels)):
    if pred_labels[i] == 1:
        color.append('y')
    else:
        color.append('r')
        
# Plot data a scatter plot
ax.scatter(test_x[:, 0], test_x[:, 1], color=color, s=1)
ax.set_ylim([-0.5, 1.5])
# Out:
# (-0.5, 1.5)
