# %%
import gpytorch
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torchvision import transforms

gpytorch.functions.use_toeplitz = False

# %%
bottleneck_size = 5

class FeatureExtractor(nn.Sequential):
    
    def __init__(self):
        super(FeatureExtractor, self).__init__(nn.Conv2d(1, 32, kernel_size=5, padding=2),
                                 nn.BatchNorm2d(32),
                                 nn.ReLU(),
                                 nn.MaxPool2d(2, 2),
                                 nn.Conv2d(32, 64, kernel_size=5, padding=2),
                                 nn.BatchNorm2d(64),
                                 nn.ReLU(),
                                 nn.MaxPool2d(2, 2))
        
class Bottleneck(nn.Sequential):
    
    def __init__(self):
        super(Bottleneck, self).__init__(nn.Linear(64*7*7, 128),
                                         nn.BatchNorm1d(128),
                                 nn.ReLU(),
                                 nn.Linear(128, 128),
                                 nn.BatchNorm1d(128),
                                 nn.ReLU(),
                                 nn.Linear(128, bottleneck_size),
                                 nn.BatchNorm1d(bottleneck_size))

class LeNet(nn.Module):
    
    def __init__(self):
        super(LeNet, self).__init__()
        self.feature_extractor = FeatureExtractor()
        self.bottleneck = Bottleneck()
        self.final_layer = nn.Sequential(
                                 nn.ReLU(),
                                 nn.Linear(bottleneck_size,10))
    
    def forward(self, x):
        features = self.feature_extractor(x)
        bottlenecked_features = self.bottleneck(features.view(-1, 64 * 7 * 7))
        classification = self.final_layer(bottlenecked_features)
        return classification

# %%
train_mnist = torchvision.datasets.MNIST('/tmp', train=True,
                                         download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ]))                                              
test_mnist = torchvision.datasets.MNIST('/tmp', train=False,
                                        download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ]))

# %%
train_data_loader = torch.utils.data.DataLoader(train_mnist, shuffle=True, pin_memory=True, batch_size=256)

# %%
criterion = nn.CrossEntropyLoss().cuda()

# %%
model = LeNet().cuda()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# %%
num_epochs = 10
for i in range(num_epochs):
    for x, y in train_data_loader:
        x = Variable(x.cuda())
        y = Variable(y.cuda())
        output = model(x)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
    print("Loss: ", loss.data[0])
# Out:
# ('Loss: ', 0.5748693943023682)
# ('Loss: ', 0.41194358468055725)
# ('Loss: ', 0.4367029368877411)
# ('Loss: ', 0.22382181882858276)
# ('Loss: ', 1.4835081100463867)
# ('Loss: ', 0.3648984432220459)
# ('Loss: ', 0.8446351885795593)
# ('Loss: ', 0.5363819003105164)
# ('Loss: ', 0.013164718635380268)
# ('Loss: ', 0.10387003421783447)

# %%
from gpytorch.kernels import RBFKernel, GridInterpolationKernel
from torch import nn, optim
from gpytorch.kernels import RBFKernel, GridInterpolationKernel
from gpytorch.means import ConstantMean
from gpytorch.likelihoods import GaussianLikelihood, BernoulliLikelihood
from gpytorch.random_variables import GaussianRandomVariable


class DeepKernel(gpytorch.Module):
    def __init__(self, model):
        super(DeepKernel, self).__init__()
        self.feature_extractor = model.feature_extractor
        self.bottleneck = model.bottleneck
        self.gp_layer = GPLayer()
        
    def forward(self, x):
        features = self.feature_extractor(x)
        bottlenecked_features = self.bottleneck(features.view(-1, 64 * 7 * 7))
        bottlenecked_features *= 0.01
        gp_output = self.gp_layer(bottlenecked_features)
        return gp_output

class LatentFunction(gpytorch.AdditiveGridInducingPointModule):
    def __init__(self):
        super(LatentFunction, self).__init__(grid_size=100, grid_bounds=[(-3, 3)])
        self.mean_module = ConstantMean(constant_bounds=(-1e-5, 1e-5))
        self.covar_module = RBFKernel(log_lengthscale_bounds=(-5, 5))
        self.register_parameter('log_outputscale', nn.Parameter(torch.Tensor([0])), bounds=(-5,6))
        
    def forward(self,x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        covar_x = covar_x.mul(self.log_outputscale.exp())
        latent_pred = GaussianRandomVariable(mean_x, covar_x)
        return latent_pred

class GPLayer(gpytorch.GPModel):
    def __init__(self):
        super(GPLayer,self).__init__(BernoulliLikelihood())
        self.latent_function = LatentFunction()
        
    def forward(self, x):
        return self.latent_function(x)

# %%
deep_kernel = DeepKernel(model).cuda()

# %%
gp_data_loader = torch.utils.data.DataLoader(train_mnist, batch_size=128, pin_memory=True)

# %%
# Find optimal model hyperparameters
deep_kernel.train()
optimizer = torch.optim.Adam(deep_kernel.gp_layer.parameters(), lr=0.005)
optimizer.n_iter = 0
num_epochs = 3
for i in range(num_epochs):
    for j, (train_x_batch, train_y_batch) in enumerate(gp_data_loader):
        train_y_batch[train_y_batch!=1]=-1
        train_x_batch = Variable(train_x_batch).cuda()
        train_y_batch = Variable(train_y_batch.cuda())
        optimizer.zero_grad()
        output = deep_kernel(train_x_batch)
        loss = -deep_kernel.gp_layer.marginal_log_likelihood(output, train_y_batch.float())
        loss.backward()
        optimizer.n_iter += 1
        print('Iter %d/%d - Loss: %.3f' % (
            i + 1, num_epochs, loss.data[0],
        ))
        optimizer.step()
    
# Set back to eval mode
deep_kernel.eval()
# Out:
# Iter 1/3 - Loss: 291.962
# Iter 1/3 - Loss: 222.469
# Iter 1/3 - Loss: 191.826
# Iter 1/3 - Loss: 264.767
# Iter 1/3 - Loss: 94.878
# Iter 1/3 - Loss: 435.070
# Iter 1/3 - Loss: 492.511
# Iter 1/3 - Loss: 443.101
# Iter 1/3 - Loss: 424.483
# Iter 1/3 - Loss: 314.415
# Iter 1/3 - Loss: 242.884
# Iter 1/3 - Loss: 366.626
# Iter 1/3 - Loss: 316.214
# Iter 1/3 - Loss: 452.091
# Iter 1/3 - Loss: 317.611
# Iter 1/3 - Loss: 312.950
# Iter 1/3 - Loss: 329.193
# Iter 1/3 - Loss: 240.427
# Iter 1/3 - Loss: 539.236
# Iter 1/3 - Loss: 559.298
# Iter 1/3 - Loss: 426.317
# Iter 1/3 - Loss: 318.377
# Iter 1/3 - Loss: 510.419
# Iter 1/3 - Loss: 395.583
# Iter 1/3 - Loss: 347.130
# Iter 1/3 - Loss: 660.529
# Iter 1/3 - Loss: 333.490
# Iter 1/3 - Loss: 230.737
# Iter 1/3 - Loss: 316.067
# Iter 1/3 - Loss: 295.117
# Iter 1/3 - Loss: 156.262
# Iter 1/3 - Loss: 432.384
# Iter 1/3 - Loss: 638.158
# Iter 1/3 - Loss: 359.473
# Iter 1/3 - Loss: 396.712
# Iter 1/3 - Loss: 495.437
# Iter 1/3 - Loss: 194.968
# Iter 1/3 - Loss: 500.123
# Iter 1/3 - Loss: 368.459
# Iter 1/3 - Loss: 366.816
# Iter 1/3 - Loss: 407.681
# Iter 1/3 - Loss: 406.951
# Iter 1/3 - Loss: 332.648
# Iter 1/3 - Loss: 504.180
# Iter 1/3 - Loss: 235.950
# Iter 1/3 - Loss: 242.623
# Iter 1/3 - Loss: 481.307
# Iter 1/3 - Loss: 396.597
# Iter 1/3 - Loss: 405.839
# Iter 1/3 - Loss: 550.958
# Iter 1/3 - Loss: 479.130
# Iter 1/3 - Loss: 416.858
# Iter 1/3 - Loss: 263.225
# Iter 1/3 - Loss: 588.385
# Iter 1/3 - Loss: 438.030
# Iter 1/3 - Loss: 332.469
# Iter 1/3 - Loss: 329.223
# Iter 1/3 - Loss: 467.184
# Iter 1/3 - Loss: 495.851
# Iter 1/3 - Loss: 467.875
# Iter 1/3 - Loss: 319.283
# Iter 1/3 - Loss: 308.453
# Iter 1/3 - Loss: 468.930
# Iter 1/3 - Loss: 344.527
# Iter 1/3 - Loss: 186.092
# Iter 1/3 - Loss: 342.299
# Iter 1/3 - Loss: 160.161
# Iter 1/3 - Loss: 312.333
# Iter 1/3 - Loss: 596.670
# Iter 1/3 - Loss: 240.309
# Iter 1/3 - Loss: 383.580
# Iter 1/3 - Loss: 265.431
# Iter 1/3 - Loss: 479.143
# Iter 1/3 - Loss: 434.653
# Iter 1/3 - Loss: 250.572
# Iter 1/3 - Loss: 502.288
# Iter 1/3 - Loss: 530.610
# Iter 1/3 - Loss: 532.170
# Iter 1/3 - Loss: 391.464
# Iter 1/3 - Loss: 296.243
# Iter 1/3 - Loss: 364.174
# Iter 1/3 - Loss: 380.904
# Iter 1/3 - Loss: 325.952
# Iter 1/3 - Loss: 178.943
# Iter 1/3 - Loss: 252.687
# Iter 1/3 - Loss: 332.625
# Iter 1/3 - Loss: 234.011
# Iter 1/3 - Loss: 341.296
# Iter 1/3 - Loss: 612.162
# Iter 1/3 - Loss: 284.489
# Iter 1/3 - Loss: 371.177
# Iter 1/3 - Loss: 466.611
# Iter 1/3 - Loss: 197.117
# Iter 1/3 - Loss: 431.960
# Iter 1/3 - Loss: 231.205
# Iter 1/3 - Loss: 162.995
# Iter 1/3 - Loss: 155.760
# Iter 1/3 - Loss: 326.872
# Iter 1/3 - Loss: 105.782
# Iter 1/3 - Loss: 383.956
# Iter 1/3 - Loss: 287.598
# Iter 1/3 - Loss: 288.508
# Iter 1/3 - Loss: 231.668
# Iter 1/3 - Loss: 292.075
# Iter 1/3 - Loss: 272.335
# Iter 1/3 - Loss: 352.096
# Iter 1/3 - Loss: 255.903
# Iter 1/3 - Loss: 523.354
# Iter 1/3 - Loss: 406.137
# Iter 1/3 - Loss: 264.455
# Iter 1/3 - Loss: 461.485
# Iter 1/3 - Loss: 321.758
# Iter 1/3 - Loss: 251.712
# Iter 1/3 - Loss: 283.973
# Iter 1/3 - Loss: 203.618
# Iter 1/3 - Loss: 288.969
# Iter 1/3 - Loss: 192.511
# Iter 1/3 - Loss: 330.372
# Iter 1/3 - Loss: 269.895
# Iter 1/3 - Loss: 237.754
# Iter 1/3 - Loss: 280.003
# Iter 1/3 - Loss: 376.783
# Iter 1/3 - Loss: 422.549
# Iter 1/3 - Loss: 314.538
# Iter 1/3 - Loss: 306.490
# Iter 1/3 - Loss: 395.626
# Iter 1/3 - Loss: 359.704
# Iter 1/3 - Loss: 268.189
# Iter 1/3 - Loss: 241.657
# Iter 1/3 - Loss: 331.709
# Iter 1/3 - Loss: 357.600
# Iter 1/3 - Loss: 382.395
# Iter 1/3 - Loss: 159.966
# Iter 1/3 - Loss: 407.826
# Iter 1/3 - Loss: 419.722
# Iter 1/3 - Loss: 147.749
# Iter 1/3 - Loss: 318.115
# Iter 1/3 - Loss: 320.668
# Iter 1/3 - Loss: 193.663
# Iter 1/3 - Loss: 236.089
# Iter 1/3 - Loss: 354.675
# Iter 1/3 - Loss: 181.778
# Iter 1/3 - Loss: 280.547
# Iter 1/3 - Loss: 364.226
# Iter 1/3 - Loss: 342.612
# Iter 1/3 - Loss: 312.019
# Iter 1/3 - Loss: 230.407
# Iter 1/3 - Loss: 215.783
# Iter 1/3 - Loss: 273.180
# Iter 1/3 - Loss: 330.551
# Iter 1/3 - Loss: 230.475
# Iter 1/3 - Loss: 250.673
# Iter 1/3 - Loss: 253.056
# Iter 1/3 - Loss: 201.756
# Iter 1/3 - Loss: 189.867
# Iter 1/3 - Loss: 202.419
# Iter 1/3 - Loss: 203.256
# Iter 1/3 - Loss: 236.390
# Iter 1/3 - Loss: 276.733
# Iter 1/3 - Loss: 148.141
# Iter 1/3 - Loss: 207.354
# Iter 1/3 - Loss: 292.052
# Iter 1/3 - Loss: 200.113
# Iter 1/3 - Loss: 198.487
# Iter 1/3 - Loss: 225.097
# Iter 1/3 - Loss: 221.741
# Iter 1/3 - Loss: 374.845
# Iter 1/3 - Loss: 94.117
# Iter 1/3 - Loss: 147.861
# Iter 1/3 - Loss: 222.464
# Iter 1/3 - Loss: 311.315
# Iter 1/3 - Loss: 174.698
# Iter 1/3 - Loss: 265.402
# Iter 1/3 - Loss: 264.694
# Iter 1/3 - Loss: 191.033
# Iter 1/3 - Loss: 296.173
# Iter 1/3 - Loss: 275.921
# Iter 1/3 - Loss: 285.728
# Iter 1/3 - Loss: 170.212
# Iter 1/3 - Loss: 195.802
# Iter 1/3 - Loss: 224.337
# Iter 1/3 - Loss: 299.524
# Iter 1/3 - Loss: 246.478
# Iter 1/3 - Loss: 104.120
# Iter 1/3 - Loss: 261.013
# Iter 1/3 - Loss: 349.247
# Iter 1/3 - Loss: 168.842
# Iter 1/3 - Loss: 155.964
# Iter 1/3 - Loss: 202.244
# Iter 1/3 - Loss: 121.860
# Iter 1/3 - Loss: 197.749
# Iter 1/3 - Loss: 175.127
# Iter 1/3 - Loss: 201.200
# Iter 1/3 - Loss: 380.780
# Iter 1/3 - Loss: 220.233
# Iter 1/3 - Loss: 230.893
# Iter 1/3 - Loss: 161.090
# Iter 1/3 - Loss: 271.200
# Iter 1/3 - Loss: 78.738
# Iter 1/3 - Loss: 208.899
# Iter 1/3 - Loss: 195.320
# Iter 1/3 - Loss: 207.756
# Iter 1/3 - Loss: 127.052
# Iter 1/3 - Loss: 209.548
# Iter 1/3 - Loss: 243.292
# Iter 1/3 - Loss: 203.308
# Iter 1/3 - Loss: 258.958
# Iter 1/3 - Loss: 143.870
# Iter 1/3 - Loss: 138.093
# Iter 1/3 - Loss: 169.976
# Iter 1/3 - Loss: 212.946
# Iter 1/3 - Loss: 201.952
# Iter 1/3 - Loss: 197.851
# Iter 1/3 - Loss: 236.715
# Iter 1/3 - Loss: 128.665
# Iter 1/3 - Loss: 235.977
# Iter 1/3 - Loss: 232.124
# Iter 1/3 - Loss: 180.237
# Iter 1/3 - Loss: 255.226
# Iter 1/3 - Loss: 196.319
# Iter 1/3 - Loss: 194.374
# Iter 1/3 - Loss: 144.479
# Iter 1/3 - Loss: 104.978
# Iter 1/3 - Loss: 223.840
# Iter 1/3 - Loss: 293.895
# Iter 1/3 - Loss: 165.761
# Iter 1/3 - Loss: 147.209
# Iter 1/3 - Loss: 213.033
# Iter 1/3 - Loss: 161.328
# Iter 1/3 - Loss: 245.880
# Iter 1/3 - Loss: 161.238
# Iter 1/3 - Loss: 191.134
# Iter 1/3 - Loss: 248.955
# Iter 1/3 - Loss: 301.309
# Iter 1/3 - Loss: 203.012
# Iter 1/3 - Loss: 340.652
# Iter 1/3 - Loss: 174.325
# Iter 1/3 - Loss: 162.511
# Iter 1/3 - Loss: 380.004
# Iter 1/3 - Loss: 167.056
# Iter 1/3 - Loss: 140.232
# Iter 1/3 - Loss: 157.060
# Iter 1/3 - Loss: 169.834
# Iter 1/3 - Loss: 137.607
# Iter 1/3 - Loss: 181.363
# Iter 1/3 - Loss: 183.186
# Iter 1/3 - Loss: 118.854
# Iter 1/3 - Loss: 267.517
# Iter 1/3 - Loss: 115.553
# Iter 1/3 - Loss: 112.335
# Iter 1/3 - Loss: 130.258
# Iter 1/3 - Loss: 171.503
# Iter 1/3 - Loss: 60.321
# Iter 1/3 - Loss: 154.252
# Iter 1/3 - Loss: 124.831
# Iter 1/3 - Loss: 195.140
# Iter 1/3 - Loss: 202.768
# Iter 1/3 - Loss: 193.636
# Iter 1/3 - Loss: 117.164
# Iter 1/3 - Loss: 152.522
# Iter 1/3 - Loss: 92.946
# Iter 1/3 - Loss: 163.986
# Iter 1/3 - Loss: 191.140
# Iter 1/3 - Loss: 164.902
# Iter 1/3 - Loss: 206.844
# Iter 1/3 - Loss: 58.046
# Iter 1/3 - Loss: 110.248
# Iter 1/3 - Loss: 185.932
# Iter 1/3 - Loss: 124.382
# Iter 1/3 - Loss: 143.421
# Iter 1/3 - Loss: 139.654
# Iter 1/3 - Loss: 102.202
# Iter 1/3 - Loss: 76.429
# Iter 1/3 - Loss: 127.046
# Iter 1/3 - Loss: 103.345
# Iter 1/3 - Loss: 147.850
# Iter 1/3 - Loss: 148.010
# Iter 1/3 - Loss: 105.289
# Iter 1/3 - Loss: 175.687
# Iter 1/3 - Loss: 217.793
# Iter 1/3 - Loss: 98.433
# Iter 1/3 - Loss: 60.897
# Iter 1/3 - Loss: 67.106
# Iter 1/3 - Loss: 126.620
# Iter 1/3 - Loss: 142.666
# Iter 1/3 - Loss: 82.226
# Iter 1/3 - Loss: 81.199
# Iter 1/3 - Loss: 71.513
# Iter 1/3 - Loss: 95.259
# Iter 1/3 - Loss: 146.688
# Iter 1/3 - Loss: 112.934
# Iter 1/3 - Loss: 136.558
# Iter 1/3 - Loss: 95.137
# Iter 1/3 - Loss: 67.957
# Iter 1/3 - Loss: 108.456
# Iter 1/3 - Loss: 72.567
# Iter 1/3 - Loss: 152.577
# Iter 1/3 - Loss: 91.862
# Iter 1/3 - Loss: 157.917
# Iter 1/3 - Loss: 87.332
# Iter 1/3 - Loss: 35.202
# Iter 1/3 - Loss: 121.516
# Iter 1/3 - Loss: 100.297
# Iter 1/3 - Loss: 62.256
# Iter 1/3 - Loss: 102.847
# Iter 1/3 - Loss: 94.006
# Iter 1/3 - Loss: 112.403
# Iter 1/3 - Loss: 37.435
# Iter 1/3 - Loss: 74.451
# Iter 1/3 - Loss: 95.965
# Iter 1/3 - Loss: 75.465
# Iter 1/3 - Loss: 61.617
# Iter 1/3 - Loss: 104.186
# Iter 1/3 - Loss: 97.139
# Iter 1/3 - Loss: 89.837
# Iter 1/3 - Loss: 116.334
# Iter 1/3 - Loss: 75.882
# Iter 1/3 - Loss: 94.561
# Iter 1/3 - Loss: 111.577
# Iter 1/3 - Loss: 89.478
# Iter 1/3 - Loss: 83.609
# Iter 1/3 - Loss: 76.798
# Iter 1/3 - Loss: 105.582
# Iter 1/3 - Loss: 92.700
# Iter 1/3 - Loss: 92.948
# Iter 1/3 - Loss: 61.934
# Iter 1/3 - Loss: 110.590
# Iter 1/3 - Loss: 71.137
# Iter 1/3 - Loss: 71.522
# Iter 1/3 - Loss: 56.693
# Iter 1/3 - Loss: 126.276
# Iter 1/3 - Loss: 31.703
# Iter 1/3 - Loss: 112.536
# Iter 1/3 - Loss: 118.965
# Iter 1/3 - Loss: 80.115
# Iter 1/3 - Loss: 182.692
# Iter 1/3 - Loss: 72.409
# Iter 1/3 - Loss: 53.449
# Iter 1/3 - Loss: 58.988
# Iter 1/3 - Loss: 131.254
# Iter 1/3 - Loss: 3.573
# Iter 1/3 - Loss: 93.605
# Iter 1/3 - Loss: 106.199
# Iter 1/3 - Loss: 22.971
# Iter 1/3 - Loss: 60.309
# Iter 1/3 - Loss: 65.180
# Iter 1/3 - Loss: 64.233
# Iter 1/3 - Loss: 86.824
# Iter 1/3 - Loss: 14.741
# Iter 1/3 - Loss: 89.412
# Iter 1/3 - Loss: 60.615
# Iter 1/3 - Loss: 113.363
# Iter 1/3 - Loss: 70.971
# Iter 1/3 - Loss: 109.663
# Iter 1/3 - Loss: 101.380
# Iter 1/3 - Loss: 87.349
# Iter 1/3 - Loss: 62.582
# Iter 1/3 - Loss: 51.176
# Iter 1/3 - Loss: 84.619
# Iter 1/3 - Loss: 39.632
# Iter 1/3 - Loss: 109.013
# Iter 1/3 - Loss: 121.465
# Iter 1/3 - Loss: 99.178
# Iter 1/3 - Loss: 102.585
# Iter 1/3 - Loss: 104.920
# Iter 1/3 - Loss: 84.282
# Iter 1/3 - Loss: 19.743
# Iter 1/3 - Loss: 30.943
# Iter 1/3 - Loss: 138.196
# Iter 1/3 - Loss: 81.957
# Iter 1/3 - Loss: 115.135
# Iter 1/3 - Loss: 106.554
# Iter 1/3 - Loss: 27.515
# Iter 1/3 - Loss: 48.097
# Iter 1/3 - Loss: 76.503
# Iter 1/3 - Loss: 57.022
# Iter 1/3 - Loss: 45.119
# Iter 1/3 - Loss: 69.574
# Iter 1/3 - Loss: 71.903
# Iter 1/3 - Loss: 54.965
# Iter 1/3 - Loss: 87.958
# Iter 1/3 - Loss: 93.904
# Iter 1/3 - Loss: 95.440
# Iter 1/3 - Loss: 109.494
# Iter 1/3 - Loss: 73.400
# Iter 1/3 - Loss: 72.443
# Iter 1/3 - Loss: 91.029
# Iter 1/3 - Loss: 19.343
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-a369bc369135> in <module>()
#      10         train_y_batch = Variable(train_y_batch.cuda())
#      11         optimizer.zero_grad()
# ---> 12         output = deep_kernel(train_x_batch)
#      13         loss = -deep_kernel.gp_layer.marginal_log_likelihood(output, train_y_batch.float())
#      14         loss.backward()
#
# /home/bw462/gpytorch/gpytorch/module.pyc in __call__(self, *inputs, **kwargs)
#      32                 raise RuntimeError('Input must be a RandomVariable or Variable, was a %s' %
#      33                                    input.__class__.__name__)
# ---> 34         outputs = self.forward(*inputs, **kwargs)
#      35         if isinstance(outputs, Variable) or isinstance(outputs, RandomVariable) or isinstance(outputs, LazyVariable):
#      36             return outputs
#
# <ipython-input-55-b950400b3190> in forward(self, x)
#      18         bottlenecked_features = self.bottleneck(features.view(-1, 64 * 7 * 7))
#      19         bottlenecked_features *= 0.01
# ---> 20         gp_output = self.gp_layer(bottlenecked_features)
#      21         return gp_output
#      22
#
# /home/bw462/gpytorch/gpytorch/gp_model.pyc in __call__(self, *args, **kwargs)
#     131         # Training or Prior mode
#     132         else:
# --> 133             output = super(GPModel, self).__call__(*args, **kwargs)
#     134             if self.conditioning:
#     135                 # Reset alpha cache
#
# /home/bw462/gpytorch/gpytorch/module.pyc in __call__(self, *inputs, **kwargs)
#      32                 raise RuntimeError('Input must be a RandomVariable or Variable, was a %s' %
#      33                                    input.__class__.__name__)
# ---> 34         outputs = self.forward(*inputs, **kwargs)
#      35         if isinstance(outputs, Variable) or isinstance(outputs, RandomVariable) or isinstance(outputs, LazyVariable):
#      36             return outputs
#
# <ipython-input-55-b950400b3190> in forward(self, x)
#      41
#      42     def forward(self, x):
# ---> 43         return self.latent_function(x)
#      44
#
# /home/bw462/gpytorch/gpytorch/inducing_points/additive_grid_inducing_point_module.pyc in __call__(self, inputs, **kwargs)
#      65             variational_mean = self.variational_mean
#      66             chol_variational_covar = self.chol_variational_covar
# ---> 67             induc_output = gpytorch.Module.__call__(self, Variable(self._inducing_points))
#      68             interp_indices, interp_values = self._compute_grid(inputs)
#      69
#
# /home/bw462/gpytorch/gpytorch/module.pyc in __call__(self, *inputs, **kwargs)
#      32                 raise RuntimeError('Input must be a RandomVariable or Variable, was a %s' %
#      33                                    input.__class__.__name__)
# ---> 34         outputs = self.forward(*inputs, **kwargs)
#      35         if isinstance(outputs, Variable) or isinstance(outputs, RandomVariable) or isinstance(outputs, LazyVariable):
#      36             return outputs
#
# <ipython-input-55-b950400b3190> in forward(self, x)
#      30     def forward(self,x):
#      31         mean_x = self.mean_module(x)
# ---> 32         covar_x = self.covar_module(x)
#      33         covar_x = covar_x.mul(self.log_outputscale.exp())
#      34         latent_pred = GaussianRandomVariable(mean_x, covar_x)
#
# /home/bw462/gpytorch/gpytorch/kernels/kernel.pyc in __call__(self, x1, x2, **params)
#      14             x2 = x2.view(-1, 1)
#      15         assert(x1.size(1) == x2.size(1))
# ---> 16         return super(Kernel, self).__call__(x1, x2, **params)
#
# /home/bw462/gpytorch/gpytorch/module.pyc in __call__(self, *inputs, **kwargs)
#      32                 raise RuntimeError('Input must be a RandomVariable or Variable, was a %s' %
#      33                                    input.__class__.__name__)
# ---> 34         outputs = self.forward(*inputs, **kwargs)
#      35         if isinstance(outputs, Variable) or isinstance(outputs, RandomVariable) or isinstance(outputs, LazyVariable):
#      36             return outputs
#
# /home/bw462/gpytorch/gpytorch/kernels/grid_interpolation_kernel.pyc in forward(self, x1, x2, **kwargs)
#      41                 else:
#      42                     for i in range(100):
# ---> 43                         k_UU = self.base_kernel_module(grid_var[0], grid_var[0], **kwargs).squeeze()
#      44                     K_XX = NonLazyVariable(k_UU)
#      45
#
# /home/bw462/gpytorch/gpytorch/kernels/kernel.pyc in __call__(self, x1, x2, **params)
#      14             x2 = x2.view(-1, 1)
#      15         assert(x1.size(1) == x2.size(1))
# ---> 16         return super(Kernel, self).__call__(x1, x2, **params)
#
# /home/bw462/gpytorch/gpytorch/module.pyc in __call__(self, *inputs, **kwargs)
#      32                 raise RuntimeError('Input must be a RandomVariable or Variable, was a %s' %
#      33                                    input.__class__.__name__)
# ---> 34         outputs = self.forward(*inputs, **kwargs)
#      35         if isinstance(outputs, Variable) or isinstance(outputs, RandomVariable) or isinstance(outputs, LazyVariable):
#      36             return outputs
#
# /home/bw462/gpytorch/gpytorch/kernels/rbf_kernel.pyc in forward(self, x1, x2)
#      23         res.sub_(x1_squared).sub_(x2_squared)  # res = -(x - z)^2
#      24
# ---> 25         res = res / (self.log_lengthscale.exp() + self.eps)  # res = -(x - z)^2 / lengthscale
#      26         res.exp_()
#      27         return res
#
# /home/bw462/gpytorch/gpytorch/module.pyc in __getattr__(self, name)
#     215                 lower_bound, upper_bound = self._bounds[name]
#     216                 lower_mask = param.data < lower_bound
# --> 217                 if lower_mask.sum():
#     218                     if torch.is_tensor(lower_bound):
#     219                         param.data.masked_scatter_(lower_mask, lower_bound[lower_mask])
#
# KeyboardInterrupt:

# %%
deep_kernel.gp_layer.condition(Variable(torch.randn(2, 2)).cuda(), Variable(torch.zeros(2)).cuda())
deep_kernel.eval()
test_data_loader = torch.utils.data.DataLoader(test_mnist, shuffle=False, pin_memory=True, batch_size=256)

for test_batch_x, test_batch_y in test_data_loader:
    predictions = deep_kernel(Variable(test_batch_x).cuda()).probability.round()
    #print(predictions)
    test_batch_y = Variable(test_batch_y.fmod(2)).cuda().float()
    print(torch.eq(predictions, test_batch_y).float().mean().data[0])
# Out:
# 0.55859375
# 0.59375
# 0.58984375
# 0.58984375
# 0.58203125
# 0.55859375
# 0.5703125
# 0.53125
# 0.5859375
# 0.5625
# 0.55078125
# 0.55078125
# 0.609375
# 0.578125
# 0.578125
# 0.5390625
# 0.53125
# 0.5625
# 0.5390625
# 0.6015625
# 0.5703125
# 0.609375
# 0.59765625
# 0.59765625
# 0.57421875
# 0.6015625
# 0.58203125
# 0.59375
# 0.60546875
# 0.5390625
# 0.59375
# 0.5546875
# 0.58984375
# 0.58203125
# 0.5859375
# 0.59765625
# 0.5703125
# 0.5234375
# 0.59765625
# 0.5

# %%
from torch.nn import functional as F

model.eval()
test_data_loader = torch.utils.data.DataLoader(test_mnist, shuffle=False, pin_memory=True, batch_size=256)

for test_batch_x, test_batch_y in test_data_loader:
    _, predictions = model(Variable(test_batch_x).cuda()).max(dim=1)
    predictions = predictions.fmod(2)
    #print(predictions)
    test_batch_y = Variable(test_batch_y).cuda().fmod(2)
    #print(test_batch_y)
    print(torch.eq(predictions, test_batch_y).float().mean().data[0])
# Out:
# 0.9765625
# 0.98046875
# 0.98828125
# 0.99609375
# 0.9765625
# 0.98828125
# 0.98828125
# 0.98828125
# 0.98046875
# 0.99609375
# 0.96875
# 0.984375
# 0.9921875
# 0.98828125
# 0.97265625
# 0.98046875
# 0.984375
# 0.96875
# 0.984375
# 0.99609375
# 0.9921875
# 1.0
# 0.98828125
# 0.984375
# 1.0
# 0.98046875
# 0.99609375
# 1.0
# 1.0
# 0.99609375
# 0.9921875
# 1.0
# 0.9921875
# 1.0
# 0.99609375
# 0.9921875
# 1.0
# 0.984375
# 0.98828125
# 1.0
