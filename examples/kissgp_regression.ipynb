# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from torch.autograd import Variable
train_x = Variable(torch.linspace(0, 1, 11))
train_y = Variable(torch.sin(train_x.data * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2)

# %%
from gpytorch.kernels import RBFKernel, GridInterpolationKernel
from gpytorch.means import ConstantMean
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch import ObservationModel
from gpytorch.random_variables import GaussianRandomVariable
from gpytorch.parameters import MLEParameterGroup, BoundedParameter

# %%
class ExactGPObservationModel(gpytorch.ObservationModel):
    def __init__(self):
        super(ExactGPObservationModel,self).__init__(GaussianLikelihood())
        self.mean_module = ConstantMean()
        self.covar_module = RBFKernel()
        self.params = MLEParameterGroup(
            log_noise=BoundedParameter(torch.Tensor([0]),-5,5),
            log_lengthscale=BoundedParameter(torch.Tensor([0]),-5,5),
        )
    
    def forward(self,x):
        mean_x = self.mean_module(x, constant=Variable(torch.Tensor([0])))
        covar_closure = lambda x: self.covar_module(x, log_lengthscale=self.params.log_lengthscale)
        grid_covar_module = GridInterpolationKernel(covar_closure,50)
        covar_x = grid_covar_module(x)
        
        latent_pred = GaussianRandomVariable(mean_x, covar_x)
        return latent_pred, self.params.log_noise

prior_observation_model = ExactGPObservationModel()

# %%
def plot_model_and_predictions(observation_model):
    f, observed_ax = plt.subplots(1, 1, figsize=(4, 3))
    test_x = Variable(torch.linspace(0, 1, 51))
    observed_pred = observation_model(test_x)

    def ax_plot(ax, rand_var, title):
        lower, upper = rand_var.confidence_region()
        ax.plot(train_x.data.numpy(), train_y.data.numpy(), 'k*')
        ax.plot(test_x.data.numpy(), rand_var.mean().data.numpy(), 'b')
        ax.fill_between(test_x.data.numpy(), lower.data.numpy(), upper.data.numpy(), alpha=0.5)
        ax.set_ylim([-3, 3])
        ax.legend(['Observed Data', 'Mean', 'Confidence'])
        ax.set_title(title)
    
    ax_plot(observed_ax, observed_pred, 'Observed Values (Likelihood)')
    
    return f

# %%
fig = plot_model_and_predictions(prior_observation_model)

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.

# %%
from gpytorch.inference import Inference
infer = Inference(prior_observation_model)
posterior_observation_model = infer.run(train_x, train_y,max_inference_steps=2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-804c9ece3246> in <module>()
#       1 from gpytorch.inference import Inference
#       2 infer = Inference(prior_observation_model)
# ----> 3 posterior_observation_model = infer.run(train_x, train_y,max_inference_steps=2)
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/inference/inference.py in run(self, train_x, train_y, optimize, **kwargs)
#      76     def run(self, train_x, train_y, optimize=True, **kwargs):
#      77         orig_observation_model = self.observation_model
# ---> 78         self.observation_model = deepcopy(self.observation_model)
#      79         new_observation_model = self.run_(train_x, train_y, optimize=optimize, **kwargs)
#      80         self.observation_model = orig_observation_model
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     188                             raise Error(
#     189                                 "un(deep)copyable object of type %s" % cls)
# --> 190                 y = _reconstruct(x, rv, 1, memo)
#     191
#     192     memo[d] = y
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in _reconstruct(x, info, deep, memo)
#     332     if state is not None:
#     333         if deep:
# --> 334             state = deepcopy(state, memo)
#     335         if hasattr(y, '__setstate__'):
#     336             y.__setstate__(state)
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in _deepcopy_dict(x, memo)
#     255     memo[id(x)] = y
#     256     for key, value in x.iteritems():
# --> 257         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     258     return y
#     259 d[dict] = _deepcopy_dict
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     188                             raise Error(
#     189                                 "un(deep)copyable object of type %s" % cls)
# --> 190                 y = _reconstruct(x, rv, 1, memo)
#     191
#     192     memo[d] = y
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in _reconstruct(x, info, deep, memo)
#     326         dictiter = None
#     327     if deep:
# --> 328         args = deepcopy(args, memo)
#     329     y = callable(*args)
#     330     memo[id(x)] = y
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in _deepcopy_tuple(x, memo)
#     235     y = []
#     236     for a in x:
# --> 237         y.append(deepcopy(a, memo))
#     238     d = id(x)
#     239     try:
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in _deepcopy_list(x, memo)
#     228     memo[id(x)] = y
#     229     for a in x:
# --> 230         y.append(deepcopy(a, memo))
#     231     return y
#     232 d[list] = _deepcopy_list
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     161     copier = _deepcopy_dispatch.get(cls)
#     162     if copier:
# --> 163         y = copier(x, memo)
#     164     else:
#     165         try:
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in _deepcopy_list(x, memo)
#     228     memo[id(x)] = y
#     229     for a in x:
# --> 230         y.append(deepcopy(a, memo))
#     231     return y
#     232 d[list] = _deepcopy_list
#
# /home/jrg365/anaconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     170             y = _deepcopy_atomic(x, memo)
#     171         else:
# --> 172             copier = getattr(x, "__deepcopy__", None)
#     173             if copier:
#     174                 y = copier(memo)
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# ...
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.pyc in __getattr__(self, name)
#      38
#      39     def __getattr__(self, name):
# ---> 40         if name == '__setstate__':
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
#
# RuntimeError: maximum recursion depth exceeded in cmp

# %%
fig = plot_model_and_predictions(posterior_observation_model)

# %%
# %debug
# Out:
# > /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.py(40)__getattr__()
#      38
#      39     def __getattr__(self, name):
# ---> 40         if name == '__setstate__':
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
#
# ipdb> name
# '_parameter_groups'
# ipdb> up
# > /mnt/c/Users/Gardn/gpytorch/gpytorch/distribution.py(43)__getattr__()
#      41             # Avoid issues with recursion when attempting deepcopy
#      42             raise AttributeError
# ---> 43         elif name in self._parameter_groups.keys():
#      44             return self._parameter_groups[name]
#      45
#
# ipdb> name
# '_parameter_groups'
# ipdb> self._parameter_groups
# *** RuntimeError: maximum recursion depth exceeded
